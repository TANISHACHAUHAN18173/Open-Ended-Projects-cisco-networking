# %% [markdown]
# <a href="https://colab.research.google.com/github/TANISHACHAUHAN18173/Open-Ended-Projects-cisco-networking/blob/main/Largest_island.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # World's largest islands
#
# This dataset `largest-islands.csv` contains information about the 100 largest islands in the world. The unit for the `area` column is km2.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/largest-islands.csv')
df.head()
# Out:
#       region      island    area                countries    climate  rank
# 0     Africa  Madagascar  591896               Madagascar    tropics     4
# 1  Antarctic   Kerguelen    6200  Antarctic Lands, France  temperate    91
# 2       Asia       Sumba   11153                Indonesia    tropics    65
# 3       Asia      Hainan   34300                    China    tropics    37
# 4       Asia      Taiwan   36198                   Taiwan    tropics    36

# %% [markdown]
# ### Project Ideas
#
# - What are the 10 largest islands in the tropics?
#
# - What are the largest islands in each `region`?
#
# - Create a line graph with `area` on the y-axis and `rank` on the x-axis. The data should be ordered by `rank`, from largest to smallest.
#
# - What islands are composed of multiple countries?

# %%
df.sort_values(by='area', ascending = False)
# Out:
#            region              island     area                    countries  \
# 41         Europe           Greenland  2166086                      Denmark
# 86        Oceania          New Guinea   821400  Papua New Guinea, Indonesia
# 23           Asia              Borneo   755000  Indonesia, Malaysia, Brunei
# 0          Africa          Madagascar   591896                   Madagascar
# 75  North America       Baffin Island   507451                       Canada
# ..            ...                 ...      ...                          ...
# 99  South America          Wellington     5556                        Chile
# 62  North America     Coats (Nunavut)     5498                       Canada
# 20           Asia                Bali     5416                    Indonesia
# 78  North America  Chichagof (Alaska)     5306                United States
# 95        Oceania         Guadalcanal     5302              Solomon Islands
#
#       climate  rank
# 41      polar     1
# 86    tropics     2
# 23    tropics     3
# 0     tropics     4
# 75      polar     5
# ..        ...   ...
# 99  temperate    95
# 62  temperate    97
# 20    tropics    98
# 78  temperate    99
# 95    tropics   100
#
# [100 rows x 6 columns]

# %%
df.head(10)
# Out:
#       region      island    area                countries    climate  rank
# 0     Africa  Madagascar  591896               Madagascar    tropics     4
# 1  Antarctic   Kerguelen    6200  Antarctic Lands, France  temperate    91
# 2       Asia       Sumba   11153                Indonesia    tropics    65
# 3       Asia      Hainan   34300                    China    tropics    37
# 4       Asia      Taiwan   36198                   Taiwan    tropics    36
# 5       Asia      Kyushu   36719                    Japan    tropics    34
# 6       Asia     Shikoku   18292                    Japan  temperate    46
# 7       Asia   Halmahera   17780                Indonesia    tropics    47
# 8       Asia       Seram   17148                Indonesia    tropics    48
# 9       Asia     Mindoro    9735              Philippines    tropics    71

# %%
df.groupby('region')['area'].max()
# Out:
# region
# Africa            591896
# Antarctic           6200
# Asia              755000
# Eurasia            76400
# Europe           2166086
# North America     507451
# Oceania           821400
# South America      47992
# Name: area, dtype: int64

# %%
df_sorted = df.sort_values(by='rank', ascending=False)
x = df_sorted['rank']
y = df_sorted['area']
plt.plot(x, y)
plt.xlabel("Rank")
plt.ylabel("Area")
plt.title("Area vs Rank (Largest to Smallest Rank)")
plt.show()

# %%
df[df['countries'].str.contains(",")]['island']
# Out:
# 1                           Kerguelen
# 23                             Borneo
# 45                            Ireland
# 50                             Cyprus
# 73                         Hispaniola
# 86                         New Guinea
# 98    Isla Grande de Tierra del Fuego
# Name: island, dtype: object
